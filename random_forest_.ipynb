# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasrimandadi/ExcelR-Training/blob/main/random_forest_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Machine learning,deep learning-RNN,LSTM,Transformer model(Bert,Self Attention mechanism,GPT)

# %%
import pandas as pd
df=pd.read_csv('https://github.com/singhrau0/Wheather-Prediction-march-batch/raw/refs/heads/main/Datasets/machine%20data/wheatherml.csv')
df
# Out:
#              Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      Partly Cloudy        rain         9.472222                  7.388889
# 1      Partly Cloudy        rain         9.355556                  7.227778
# 2      Mostly Cloudy        rain         9.377778                  9.377778
# 3      Partly Cloudy        rain         8.288889                  5.944444
# 4      Mostly Cloudy        rain         8.755556                  6.977778
# ...              ...         ...              ...                       ...
# 96448  Partly Cloudy        rain        26.016667                 26.016667
# 96449  Partly Cloudy        rain        24.583333                 24.583333
# 96450  Partly Cloudy        rain        22.038889                 22.038889
# 96451  Partly Cloudy        rain        21.522222                 21.522222
# 96452  Partly Cloudy        rain        20.438889                 20.438889
#
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Summary                   96453 non-null  object
#  1   Precip Type               96453 non-null  object
#  2   Temperature (C)           96453 non-null  float64
#  3   Apparent Temperature (C)  96453 non-null  float64
#  4   Humidity                  96453 non-null  float64
#  5   Wind Speed (km/h)         96453 non-null  float64
#  6   Wind Bearing (degrees)    96453 non-null  int64
#  7   Visibility (km)           96453 non-null  float64
#  8   Pressure (millibars)      96453 non-null  float64
#  9   Daily Summary             96453 non-null  object
#  10  year                      96453 non-null  int64
#  11  day                       96453 non-null  int64
#  12  month                     96453 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Pressure (millibars)        0
# Daily Summary               0
# year                        0
# day                         0
# month                       0
# Summary_encode              0
# precip_encode               0
# daily_encode                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
#need to predict daily summary based on rest of the data
#create x , y data

# %%
x=df.drop(columns=['daily_encode','Summary','Daily Summary','Precip Type'],axis=1)

# %%
y=df['daily_encode']

# %%
model=RandomForestClassifier()
model.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
model.predict([x.iloc[0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([197])

# %%
df[df['daily_encode']==197]
# Out:
#              Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      Partly Cloudy        rain         9.472222                  7.388889
# 1      Partly Cloudy        rain         9.355556                  7.227778
# 2      Mostly Cloudy        rain         9.377778                  9.377778
# 3      Partly Cloudy        rain         8.288889                  5.944444
# 4      Mostly Cloudy        rain         8.755556                  6.977778
# ...              ...         ...              ...                       ...
# 96400  Partly Cloudy        rain        23.838889                 23.838889
# 96401  Partly Cloudy        rain        21.005556                 21.005556
# 96402  Partly Cloudy        rain        19.838889                 19.838889
# 96403  Partly Cloudy        rain        18.727778                 18.727778
# 96404  Partly Cloudy        rain        17.661111                 17.661111
#
# ...

# %%
model.score(x,y)
# Out:
# 0.999917058048998
